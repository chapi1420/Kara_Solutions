# %%
import os
import sys

# %%
sys.path.append(os.path.abspath('..'))

# %%
from scripts.yolo import YOLOObjectDetector

# %%
img_path = '/home/nahomnadew/Desktop/10x/week7/Kara_Solutions/data/photos'

# %% [markdown]
# passing the required informations to out class

# %%
db_config = {
        'dbname': 'yolo_db',
        'user': 'postgres',
        'password': 'asdqwe456789',
        'host': 'localhost',
        'port': 5432
    }
yolo = YOLOObjectDetector(img_path, db_config)
# Out:
# Using cache found in /home/nahomnadew/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 v7.0-398-g5cdad892 Python-3.12.3 torch-2.6.0+cu124 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %% [markdown]
# detecting objects in the provided pictures

# %%
yolo.detect_objects()
# Out:
# /home/nahomnadew/Desktop/10x/week7/Kara_Solutions/yolov5/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nahomnadew/Desktop/10x/week7/Kara_Solutions/yolov5/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nahomnadew/Desktop/10x/week7/Kara_Solutions/yolov5/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nahomnadew/Desktop/10x/week7/Kara_Solutions/yolov5/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# ...

# %% [markdown]
# saving the result acquired into database

# %%
yolo.store_results_in_db()
